# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating path
path = r'C:\Users\tomas\09-04-2024 World Happiness'

# %%
df_15 = pd.read_csv(os.path.join(path, '01 Data', 'Prepared Data', '2015_cleaned.csv'), index_col = False)

# %%
df_16 = pd.read_csv(os.path.join(path, '01 Data', 'Prepared Data', '2016_cleaned.csv'), index_col = False)

# %%
df_17 = pd.read_csv(os.path.join(path, '01 Data', 'Prepared Data', '2017_cleaned.csv'), index_col = False)

# %%
df_18 = pd.read_csv(os.path.join(path, '01 Data', 'Prepared Data', '2018_cleaned.csv'), index_col = False)

# %%
df_19 = pd.read_csv(os.path.join(path, '01 Data', 'Prepared Data', '2019_cleaned.csv'), index_col = False)

# %%
# Adding new column "year" and filling the rows with the correct year for the data set
df_15.loc[:, "Year"] = "2015"

# %%
df_15.head()
# Out:
#    Unnamed: 0      Country  Happiness Rank  Happiness Score  \
# 0           0  Switzerland               1            7.587
# 1           1      Iceland               2            7.561
# 2           2      Denmark               3            7.527
# 3           3       Norway               4            7.522
# 4           4       Canada               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Year
# 0                        0.41978     0.29678  2015
# 1                        0.14145     0.43630  2015
# ...

# %%
df_15.isnull().sum()
# Out:
# Unnamed: 0                       0
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Year                             0
# dtype: int64

# %%
df_16.loc[:, "Year"] = "2016"

# %%
df_17.loc[:, "Year"] = "2017"

# %%
df_18.loc[:, "Year"] = "2018"

# %%
df_19.loc[:, "Year"] = "2019"

# %%
#Drop unnamed columns in df_prods
df_15 = df_15.drop(columns = ['Unnamed: 0'])

# %%
df_15
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 153       Rwanda             154            3.465                   0.22208
# 154        Benin             155            3.340                   0.28665
# 155        Syria             156            3.006                   0.66320
# 156      Burundi             157            2.905                   0.01530
# 157         Togo             158            2.839                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
#Drop unnamed columns in df_prods
df_16 = df_16.drop(columns = ['Unnamed: 0'])

# %%
#Drop unnamed columns in df_prods
df_17 = df_17.drop(columns = ['Unnamed: 0'])

# %%
#Drop unnamed columns in df_prods
df_18 = df_18.drop(columns = ['Unnamed: 0'])

# %%
#Drop unnamed columns in df_prods
df_19 = df_19.drop(columns = ['Unnamed: 0'])

# %%
df_16.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Denmark               1            7.526                   1.44178
# 1  Switzerland               2            7.509                   1.52733
# 2      Iceland               3            7.501                   1.42666
# 3       Norway               4            7.498                   1.57744
# 4      Finland               5            7.413                   1.40598
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.16374                   0.79504  0.57941                        0.44453
# 1  1.14524                   0.86303  0.58557                        0.41203
# 2  1.18326                   0.86733  0.56624                        0.14975
# 3  1.12690                   0.79579  0.59609                        0.35776
# 4  1.13464                   0.81091  0.57104                        0.41004
#
#    Generosity  Year
# 0     0.36171  2016
# ...

# %%
df_17.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health (Life Expectancy)   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust (Government Corruption)  Year
# 0                       0.315964  2017
# 1                       0.400770  2017
# ...

# %%
df_18.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.632                     1.305
# 1               2       Norway            7.594                     1.456
# 2               3      Denmark            7.555                     1.351
# 3               4      Iceland            7.495                     1.343
# 4               5  Switzerland            7.487                     1.420
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.592                     0.874    0.681       0.202
# 1   1.582                     0.861    0.686       0.286
# 2   1.590                     0.868    0.683       0.284
# 3   1.644                     0.914    0.677       0.353
# 4   1.549                     0.927    0.660       0.256
#
#    Trust (Government Corruption)  Year
# 0                          0.393  2018
# 1                          0.340  2018
# 2                          0.408  2018
# ...

# %%
df_19.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.587                     0.986    0.596       0.153
# 1   1.573                     0.996    0.592       0.252
# 2   1.582                     1.028    0.603       0.271
# 3   1.624                     1.026    0.591       0.354
# 4   1.522                     0.999    0.557       0.322
#
#    Trust (Government Corruption)  Year
# 0                          0.393  2019
# 1                          0.410  2019
# 2                          0.341  2019
# ...

# %%
result = pd.concat([df_15, df_16, df_17, df_18, df_19])

# %%
result
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
# 155               South Sudan             156            2.853
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %%
result['Year'] = result['Year'].astype('str')

# %%
result['Year'].dtype
# Out:
# dtype('O')

# %%
result.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      782.000000       782.000000                782.000000  782.000000
# mean        78.698210         5.379018                  0.916047    1.078392
# std         45.182384         1.127456                  0.407340    0.329548
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         40.000000         4.509750                  0.606500    0.869363
# 50%         79.000000         5.322000                  0.982205    1.124735
# 75%        118.000000         6.189500                  1.236187    1.327250
# max        158.000000         7.769000                  2.096000    1.644000
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                782.000000  782.000000                     781.000000
# mean                   0.612416    0.411091                       0.125436
# ...

# %%
# exporting dataset as pickle format
result.to_pickle(os.path.join(path, '01 Data', 'Prepared Data', 'merged_.pkl'))
